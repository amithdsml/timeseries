# %% [markdown]
# ## Time series Forecasting

# %% [markdown]
# ### MOVING AVERAGE

# %%
import pandas as pd

# %%
wsb_df = pd.read_csv('data/wsb.csv')

# %%
wsb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Month                  48 non-null     int64
#  1   Sale Quantity          48 non-null     int64
#  2   Promotion Expenses     48 non-null     int64
#  3   Competition Promotion  48 non-null     int64
# dtypes: int64(4)
# memory usage: 1.6 KB

# %% [markdown]
# ### Visualize the SALE QUANTITY across months

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sn

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(10,5))
plt.xlabel("Months")
plt.ylabel("Quantity")
plt.plot(wsb_df['Sale Quantity'])

# %%
wsb_df['mvg_avg'] = wsb_df['Sale Quantity'].rolling(window=12).mean().shift(1)

# %%
wsb_df.tail()
# Out:
#     Month  Sale Quantity  Promotion Expenses  Competition Promotion  \
# 43     44        3621034                 125                      0
# 44     45        5162201                 170                      0
# 45     46        4627177                 160                      0
# 46     47        4623945                 168                      0
# 47     48        4599368                 166                      0
#
#          mvg_avg
# 43  3.946629e+06
# 44  3.940490e+06
# 45  4.052117e+06
# 46  4.130275e+06
# 47  4.204882e+06

# %%
pd.set_option('display.float_format', lambda x: '%.2f' %x)

# %%
wsb_df[['Sale Quantity','mvg_avg']][10:]
# Out:
#     Sale Quantity    mvg_avg
# 10        3279115        NaN
# 11        2843766        NaN
# 12        4447581 3503418.00
# 13        3675305 3623827.58
# 14        3477156 3563306.92
# 15        3720794 3585963.33
# 16        3834086 3542250.42
# 17        3888913 3611595.92
# 18        3871342 3570858.17
# 19        3679862 3660274.75
# 20        3358242 3608290.92
# 21        3361488 3641629.00
# 22        3670362 3619804.17
# 23        3123966 3652408.08
# 24        4634047 3675758.08
# 25        3772879 3691296.92
# 26        3187110 3699428.08
# 27        3093683 3675257.58
# 28        4557363 3622998.33
# 29        3816956 3683271.42
# 30        4410887 3677275.00
# 31        3694713 3722237.08
# 32        3822669 3723474.67
# 33        3689286 3762176.92
# 34        3728654 3789493.42
# 35        4732677 3794351.08
# 36        3216483 3928410.33
# 37        3453239 3810280.00
# 38        5431651 3783643.33
# 39        4241851 3970688.42
# 40        3909887 4066369.08
# ...

# %%
plt.figure(figsize=(10,5))
plt.xlabel("Months")
plt.ylabel("Quantity")
plt.plot(wsb_df['Sale Quantity'][12:])
plt.plot(wsb_df['mvg_avg'][12:],'*')
# plt.legend()

# %% [markdown]
# ## Calculating forecast accuracy
# >1. RMSE
# >2. MAPE

# %%
def get_mape(actual, predicted):
    y_ture, y_pred = np.array(actual), np.array(predicted)
    return np.round(np.mean(np.abs((actual-predicted)/actual))*100,2)

# %%
import numpy as np

# %%
get_mape(wsb_df['Sale Quantity'][36:].values,
        wsb_df['mvg_avg'][36:].values)
# Out:
# 14.04

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(wsb_df['Sale Quantity'][36:].values,
        wsb_df['mvg_avg'][36:].values))
# Out:
# 734725.8359239782
